# %% [markdown]
# # 0. Setup Paths

# %%
import os

# %%
CUSTOM_MODEL_NAME = 'my_ssd_mobnet' 
PRETRAINED_MODEL_NAME = 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8'
PRETRAINED_MODEL_URL = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz'
TF_RECORD_SCRIPT_NAME = 'generate_tfrecord.py'
LABEL_MAP_NAME = 'label_map.pbtxt'

# %%
paths = {
    'WORKSPACE_PATH': os.path.join('Tensorflow', 'workspace'),
    'SCRIPTS_PATH': os.path.join('Tensorflow','scripts'),
    'APIMODEL_PATH': os.path.join('Tensorflow','models'),
    'ANNOTATION_PATH': os.path.join('Tensorflow', 'workspace','annotations'),
    'IMAGE_PATH': os.path.join('Tensorflow', 'workspace','images'),
    'MODEL_PATH': os.path.join('Tensorflow', 'workspace','models'),
    'PRETRAINED_MODEL_PATH': os.path.join('Tensorflow', 'workspace','pre-trained-models'),
    'CHECKPOINT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME), 
    'OUTPUT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'export'), 
    'TFJS_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfjsexport'), 
    'TFLITE_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfliteexport'), 
    'PROTOC_PATH':os.path.join('Tensorflow','protoc')
 }

# %%
files = {
    'PIPELINE_CONFIG':os.path.join('Tensorflow', 'workspace','models', CUSTOM_MODEL_NAME, 'pipeline.config'),
    'TF_RECORD_SCRIPT': os.path.join(paths['SCRIPTS_PATH'], TF_RECORD_SCRIPT_NAME), 
    'LABELMAP': os.path.join(paths['ANNOTATION_PATH'], LABEL_MAP_NAME)
}

# %%
for path in paths.values():
    if not os.path.exists(path):
        if os.name == 'posix':
            # !mkdir -p {path}
        if os.name == 'nt':
            # !mkdir {path}

# %% [markdown]
# # 1. Download TF Models Pretrained Models from Tensorflow Model Zoo and Install TFOD

# %%
# https://www.tensorflow.org/install/source_windows

# %%
if os.name=='nt':
    # !pip install wget
    import wget
# Out:
# Requirement already satisfied: wget in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (3.2)

# %%
if not os.path.exists(os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection')):
    # !git clone https://github.com/tensorflow/models {paths['APIMODEL_PATH']}
# Out:
# Cloning into 'Tensorflow/models'...
# remote: Enumerating objects: 68832, done.
# remote: Total 68832 (delta 0), reused 0 (delta 0), pack-reused 68832
# Receiving objects: 100% (68832/68832), 577.12 MiB | 12.98 MiB/s, done.
# Resolving deltas: 100% (48516/48516), done.
# Updating files: 100% (2882/2882), done.

# %%
# Install Tensorflow Object Detection 
if os.name=='posix':  
    # !apt-get install protobuf-compiler
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && cp object_detection/packages/tf2/setup.py . && python -m pip install . 
    
if os.name=='nt':
    url="https://github.com/protocolbuffers/protobuf/releases/download/v3.15.6/protoc-3.15.6-win64.zip"
    wget.download(url)
    # !move protoc-3.15.6-win64.zip {paths['PROTOC_PATH']}
    # !cd {paths['PROTOC_PATH']} && tar -xf protoc-3.15.6-win64.zip
    os.environ['PATH'] += os.pathsep + os.path.abspath(os.path.join(paths['PROTOC_PATH'], 'bin'))   
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && copy object_detection\\packages\\tf2\\setup.py setup.py && python setup.py build && python setup.py install
    # !cd Tensorflow/models/research/slim && pip install -e .
# Out:
# 100% [..........................................................................] 1468733 / 1468733
#         1 file(s) moved.
#         1 file(s) copied.
# running build
# running build_py
# copying object_detection\protos\anchor_generator_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\argmax_matcher_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\bipartite_matcher_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\box_coder_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\box_predictor_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\calibration_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\center_net_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\eval_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\faster_rcnn_box_coder_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\faster_rcnn_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\flexible_grid_anchor_generator_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\fpn_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\graph_rewriter_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\grid_anchor_generator_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\hyperparams_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\image_resizer_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\input_reader_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\keypoint_box_coder_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\losses_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\matcher_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\mean_stddev_box_coder_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\model_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\multiscale_anchor_generator_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\optimizer_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\pipeline_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\post_processing_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\preprocessor_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\region_similarity_calculator_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\square_box_coder_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\ssd_anchor_generator_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\ssd_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\string_int_label_map_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\target_assigner_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\train_pb2.py -> build\lib\object_detection\protos
# running egg_info
# writing manifest file 'object_detection.egg-info\SOURCES.txt'
# running install
# running bdist_egg
# running egg_info
# writing manifest file 'object_detection.egg-info\SOURCES.txt'
# running install_lib
# running build_py
# creating build\bdist.win-amd64\egg
# creating build\bdist.win-amd64\egg\datasets
# creating build\bdist.win-amd64\egg\deployment
# creating build\bdist.win-amd64\egg\nets
# creating build\bdist.win-amd64\egg\nets\mobilenet
# creating build\bdist.win-amd64\egg\nets\nasnet
# creating build\bdist.win-amd64\egg\object_detection
# creating build\bdist.win-amd64\egg\object_detection\anchor_generators
# creating build\bdist.win-amd64\egg\object_detection\box_coders
# creating build\bdist.win-amd64\egg\object_detection\builders
# creating build\bdist.win-amd64\egg\object_detection\core
# creating build\bdist.win-amd64\egg\object_detection\dataset_tools
# creating build\bdist.win-amd64\egg\object_detection\dataset_tools\context_rcnn
# creating build\bdist.win-amd64\egg\object_detection\data_decoders
# creating build\bdist.win-amd64\egg\object_detection\inference
# creating build\bdist.win-amd64\egg\object_detection\legacy
# creating build\bdist.win-amd64\egg\object_detection\matchers
# creating build\bdist.win-amd64\egg\object_detection\meta_architectures
# creating build\bdist.win-amd64\egg\object_detection\metrics
# creating build\bdist.win-amd64\egg\object_detection\models
# creating build\bdist.win-amd64\egg\object_detection\models\keras_models
# creating build\bdist.win-amd64\egg\object_detection\predictors
# creating build\bdist.win-amd64\egg\object_detection\predictors\heads
# creating build\bdist.win-amd64\egg\object_detection\protos
# creating build\bdist.win-amd64\egg\object_detection\tpu_exporters
# creating build\bdist.win-amd64\egg\object_detection\tpu_exporters\testdata
# creating build\bdist.win-amd64\egg\object_detection\utils
# creating build\bdist.win-amd64\egg\preprocessing
# byte-compiling build\bdist.win-amd64\egg\datasets\build_imagenet_data.py to build_imagenet_data.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\datasets\cifar10.py to cifar10.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\datasets\dataset_factory.py to dataset_factory.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\datasets\dataset_utils.py to dataset_utils.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\datasets\download_and_convert_cifar10.py to download_and_convert_cifar10.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\datasets\download_and_convert_flowers.py to download_and_convert_flowers.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\datasets\download_and_convert_mnist.py to download_and_convert_mnist.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\datasets\download_and_convert_visualwakewords.py to download_and_convert_visualwakewords.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\datasets\download_and_convert_visualwakewords_lib.py to download_and_convert_visualwakewords_lib.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\datasets\flowers.py to flowers.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\datasets\imagenet.py to imagenet.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\datasets\mnist.py to mnist.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\datasets\preprocess_imagenet_validation_data.py to preprocess_imagenet_validation_data.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\datasets\process_bounding_boxes.py to process_bounding_boxes.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\datasets\visualwakewords.py to visualwakewords.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\datasets\__init__.py to __init__.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\deployment\model_deploy.py to model_deploy.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\deployment\model_deploy_test.py to model_deploy_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\deployment\__init__.py to __init__.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\alexnet.py to alexnet.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\alexnet_test.py to alexnet_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\cifarnet.py to cifarnet.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\cyclegan.py to cyclegan.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\cyclegan_test.py to cyclegan_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\dcgan.py to dcgan.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\dcgan_test.py to dcgan_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\i3d.py to i3d.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\i3d_test.py to i3d_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\i3d_utils.py to i3d_utils.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\inception.py to inception.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\inception_resnet_v2.py to inception_resnet_v2.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\inception_resnet_v2_test.py to inception_resnet_v2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\inception_utils.py to inception_utils.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\inception_v1.py to inception_v1.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\inception_v1_test.py to inception_v1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\inception_v2.py to inception_v2.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\inception_v2_test.py to inception_v2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\inception_v3.py to inception_v3.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\inception_v3_test.py to inception_v3_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\inception_v4.py to inception_v4.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\inception_v4_test.py to inception_v4_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\lenet.py to lenet.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\mobilenet\conv_blocks.py to conv_blocks.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\mobilenet\mobilenet.py to mobilenet.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\mobilenet\mobilenet_v2.py to mobilenet_v2.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\mobilenet\mobilenet_v2_test.py to mobilenet_v2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\mobilenet\mobilenet_v3.py to mobilenet_v3.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\mobilenet\mobilenet_v3_test.py to mobilenet_v3_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\mobilenet\__init__.py to __init__.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\mobilenet_v1.py to mobilenet_v1.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\mobilenet_v1_eval.py to mobilenet_v1_eval.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\mobilenet_v1_test.py to mobilenet_v1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\mobilenet_v1_train.py to mobilenet_v1_train.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\nasnet\nasnet.py to nasnet.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\nasnet\nasnet_test.py to nasnet_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\nasnet\nasnet_utils.py to nasnet_utils.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\nasnet\nasnet_utils_test.py to nasnet_utils_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\nasnet\pnasnet.py to pnasnet.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\nasnet\pnasnet_test.py to pnasnet_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\nasnet\__init__.py to __init__.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\nets_factory.py to nets_factory.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\nets_factory_test.py to nets_factory_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\overfeat.py to overfeat.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\overfeat_test.py to overfeat_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\pix2pix.py to pix2pix.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\pix2pix_test.py to pix2pix_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\post_training_quantization.py to post_training_quantization.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\resnet_utils.py to resnet_utils.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\resnet_v1.py to resnet_v1.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\resnet_v1_test.py to resnet_v1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\resnet_v2.py to resnet_v2.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\resnet_v2_test.py to resnet_v2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\s3dg.py to s3dg.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\s3dg_test.py to s3dg_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\vgg.py to vgg.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\vgg_test.py to vgg_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\__init__.py to __init__.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\anchor_generators\flexible_grid_anchor_generator.py to flexible_grid_anchor_generator.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\anchor_generators\flexible_grid_anchor_generator_test.py to flexible_grid_anchor_generator_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\anchor_generators\grid_anchor_generator.py to grid_anchor_generator.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\anchor_generators\grid_anchor_generator_test.py to grid_anchor_generator_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\anchor_generators\multiple_grid_anchor_generator.py to multiple_grid_anchor_generator.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\anchor_generators\multiple_grid_anchor_generator_test.py to multiple_grid_anchor_generator_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\anchor_generators\multiscale_grid_anchor_generator.py to multiscale_grid_anchor_generator.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\anchor_generators\multiscale_grid_anchor_generator_test.py to multiscale_grid_anchor_generator_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\anchor_generators\__init__.py to __init__.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\box_coders\faster_rcnn_box_coder.py to faster_rcnn_box_coder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\box_coders\faster_rcnn_box_coder_test.py to faster_rcnn_box_coder_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\box_coders\keypoint_box_coder.py to keypoint_box_coder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\box_coders\keypoint_box_coder_test.py to keypoint_box_coder_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\box_coders\mean_stddev_box_coder.py to mean_stddev_box_coder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\box_coders\mean_stddev_box_coder_test.py to mean_stddev_box_coder_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\box_coders\square_box_coder.py to square_box_coder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\box_coders\square_box_coder_test.py to square_box_coder_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\box_coders\__init__.py to __init__.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\anchor_generator_builder.py to anchor_generator_builder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\anchor_generator_builder_test.py to anchor_generator_builder_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\box_coder_builder.py to box_coder_builder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\box_coder_builder_test.py to box_coder_builder_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\box_predictor_builder.py to box_predictor_builder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\box_predictor_builder_test.py to box_predictor_builder_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\calibration_builder.py to calibration_builder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\calibration_builder_test.py to calibration_builder_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\dataset_builder.py to dataset_builder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\dataset_builder_test.py to dataset_builder_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\decoder_builder.py to decoder_builder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\decoder_builder_test.py to decoder_builder_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\graph_rewriter_builder.py to graph_rewriter_builder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\graph_rewriter_builder_tf1_test.py to graph_rewriter_builder_tf1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\hyperparams_builder.py to hyperparams_builder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\hyperparams_builder_test.py to hyperparams_builder_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\image_resizer_builder.py to image_resizer_builder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\image_resizer_builder_test.py to image_resizer_builder_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\input_reader_builder.py to input_reader_builder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\input_reader_builder_tf1_test.py to input_reader_builder_tf1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\losses_builder.py to losses_builder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\losses_builder_test.py to losses_builder_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\matcher_builder.py to matcher_builder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\matcher_builder_test.py to matcher_builder_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\model_builder.py to model_builder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\model_builder_test.py to model_builder_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\model_builder_tf1_test.py to model_builder_tf1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\model_builder_tf2_test.py to model_builder_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\optimizer_builder.py to optimizer_builder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\optimizer_builder_tf1_test.py to optimizer_builder_tf1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\optimizer_builder_tf2_test.py to optimizer_builder_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\post_processing_builder.py to post_processing_builder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\post_processing_builder_test.py to post_processing_builder_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\preprocessor_builder.py to preprocessor_builder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\preprocessor_builder_test.py to preprocessor_builder_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\region_similarity_calculator_builder.py to region_similarity_calculator_builder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\region_similarity_calculator_builder_test.py to region_similarity_calculator_builder_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\target_assigner_builder.py to target_assigner_builder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\target_assigner_builder_test.py to target_assigner_builder_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\__init__.py to __init__.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\anchor_generator.py to anchor_generator.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\balanced_positive_negative_sampler.py to balanced_positive_negative_sampler.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\balanced_positive_negative_sampler_test.py to balanced_positive_negative_sampler_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\batcher.py to batcher.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\batcher_tf1_test.py to batcher_tf1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\batch_multiclass_nms_test.py to batch_multiclass_nms_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\box_coder.py to box_coder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\box_coder_test.py to box_coder_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\box_list.py to box_list.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\box_list_ops.py to box_list_ops.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\box_list_ops_test.py to box_list_ops_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\box_list_test.py to box_list_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\box_predictor.py to box_predictor.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\class_agnostic_nms_test.py to class_agnostic_nms_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\data_decoder.py to data_decoder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\data_parser.py to data_parser.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\densepose_ops.py to densepose_ops.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\densepose_ops_test.py to densepose_ops_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\freezable_batch_norm.py to freezable_batch_norm.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\freezable_batch_norm_tf2_test.py to freezable_batch_norm_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\freezable_sync_batch_norm.py to freezable_sync_batch_norm.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\keypoint_ops.py to keypoint_ops.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\keypoint_ops_test.py to keypoint_ops_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\losses.py to losses.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\losses_test.py to losses_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\matcher.py to matcher.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\matcher_test.py to matcher_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\minibatch_sampler.py to minibatch_sampler.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\minibatch_sampler_test.py to minibatch_sampler_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\model.py to model.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\model_test.py to model_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\multiclass_nms_test.py to multiclass_nms_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\post_processing.py to post_processing.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\prefetcher.py to prefetcher.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\prefetcher_tf1_test.py to prefetcher_tf1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\preprocessor.py to preprocessor.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\preprocessor_cache.py to preprocessor_cache.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\preprocessor_test.py to preprocessor_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\region_similarity_calculator.py to region_similarity_calculator.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\region_similarity_calculator_test.py to region_similarity_calculator_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\standard_fields.py to standard_fields.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\target_assigner.py to target_assigner.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\target_assigner_test.py to target_assigner_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\__init__.py to __init__.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\context_rcnn\add_context_to_examples.py to add_context_to_examples.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\context_rcnn\add_context_to_examples_tf2_test.py to add_context_to_examples_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\context_rcnn\create_cococameratraps_tfexample_main.py to create_cococameratraps_tfexample_main.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\context_rcnn\create_cococameratraps_tfexample_tf2_test.py to create_cococameratraps_tfexample_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\context_rcnn\generate_detection_data.py to generate_detection_data.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\context_rcnn\generate_detection_data_tf2_test.py to generate_detection_data_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\context_rcnn\generate_embedding_data.py to generate_embedding_data.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\context_rcnn\generate_embedding_data_tf2_test.py to generate_embedding_data_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\context_rcnn\__init__.py to __init__.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\create_ava_actions_tf_record.py to create_ava_actions_tf_record.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\create_coco_tf_record.py to create_coco_tf_record.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\create_coco_tf_record_test.py to create_coco_tf_record_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\create_kitti_tf_record.py to create_kitti_tf_record.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\create_kitti_tf_record_test.py to create_kitti_tf_record_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\create_oid_tf_record.py to create_oid_tf_record.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\create_pascal_tf_record.py to create_pascal_tf_record.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\create_pascal_tf_record_test.py to create_pascal_tf_record_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\create_pet_tf_record.py to create_pet_tf_record.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\oid_hierarchical_labels_expansion.py to oid_hierarchical_labels_expansion.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\oid_hierarchical_labels_expansion_test.py to oid_hierarchical_labels_expansion_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\oid_tfrecord_creation.py to oid_tfrecord_creation.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\oid_tfrecord_creation_test.py to oid_tfrecord_creation_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\seq_example_util.py to seq_example_util.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\seq_example_util_test.py to seq_example_util_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\tf_record_creation_util.py to tf_record_creation_util.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\tf_record_creation_util_test.py to tf_record_creation_util_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\__init__.py to __init__.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\data_decoders\tf_example_decoder.py to tf_example_decoder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\data_decoders\tf_example_decoder_test.py to tf_example_decoder_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\data_decoders\tf_sequence_example_decoder.py to tf_sequence_example_decoder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\data_decoders\tf_sequence_example_decoder_test.py to tf_sequence_example_decoder_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\data_decoders\__init__.py to __init__.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\eval_util.py to eval_util.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\eval_util_test.py to eval_util_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\exporter.py to exporter.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\exporter_lib_tf2_test.py to exporter_lib_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\exporter_lib_v2.py to exporter_lib_v2.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\exporter_main_v2.py to exporter_main_v2.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\exporter_tf1_test.py to exporter_tf1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\export_inference_graph.py to export_inference_graph.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\export_tflite_graph_lib_tf2.py to export_tflite_graph_lib_tf2.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\export_tflite_graph_lib_tf2_test.py to export_tflite_graph_lib_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\export_tflite_graph_tf2.py to export_tflite_graph_tf2.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\export_tflite_ssd_graph.py to export_tflite_ssd_graph.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\export_tflite_ssd_graph_lib.py to export_tflite_ssd_graph_lib.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\export_tflite_ssd_graph_lib_tf1_test.py to export_tflite_ssd_graph_lib_tf1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\inference\detection_inference.py to detection_inference.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\inference\detection_inference_tf1_test.py to detection_inference_tf1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\inference\infer_detections.py to infer_detections.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\inference\__init__.py to __init__.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\inputs.py to inputs.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\inputs_test.py to inputs_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\legacy\eval.py to eval.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\legacy\evaluator.py to evaluator.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\legacy\train.py to train.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\legacy\trainer.py to trainer.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\legacy\trainer_tf1_test.py to trainer_tf1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\legacy\__init__.py to __init__.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\matchers\argmax_matcher.py to argmax_matcher.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\matchers\argmax_matcher_test.py to argmax_matcher_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\matchers\bipartite_matcher.py to bipartite_matcher.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\matchers\bipartite_matcher_tf1_test.py to bipartite_matcher_tf1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\matchers\hungarian_matcher.py to hungarian_matcher.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\matchers\hungarian_matcher_tf2_test.py to hungarian_matcher_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\matchers\__init__.py to __init__.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\meta_architectures\center_net_meta_arch.py to center_net_meta_arch.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\meta_architectures\center_net_meta_arch_tf2_test.py to center_net_meta_arch_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\meta_architectures\context_rcnn_lib.py to context_rcnn_lib.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\meta_architectures\context_rcnn_lib_tf1_test.py to context_rcnn_lib_tf1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\meta_architectures\context_rcnn_lib_tf2.py to context_rcnn_lib_tf2.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\meta_architectures\context_rcnn_lib_tf2_test.py to context_rcnn_lib_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\meta_architectures\context_rcnn_meta_arch.py to context_rcnn_meta_arch.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\meta_architectures\context_rcnn_meta_arch_test.py to context_rcnn_meta_arch_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\meta_architectures\deepmac_meta_arch.py to deepmac_meta_arch.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\meta_architectures\deepmac_meta_arch_test.py to deepmac_meta_arch_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\meta_architectures\faster_rcnn_meta_arch.py to faster_rcnn_meta_arch.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\meta_architectures\faster_rcnn_meta_arch_test.py to faster_rcnn_meta_arch_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\meta_architectures\faster_rcnn_meta_arch_test_lib.py to faster_rcnn_meta_arch_test_lib.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\meta_architectures\rfcn_meta_arch.py to rfcn_meta_arch.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\meta_architectures\rfcn_meta_arch_test.py to rfcn_meta_arch_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\meta_architectures\ssd_meta_arch.py to ssd_meta_arch.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\meta_architectures\ssd_meta_arch_test.py to ssd_meta_arch_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\meta_architectures\ssd_meta_arch_test_lib.py to ssd_meta_arch_test_lib.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\meta_architectures\__init__.py to __init__.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\calibration_evaluation.py to calibration_evaluation.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\calibration_evaluation_tf1_test.py to calibration_evaluation_tf1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\calibration_metrics.py to calibration_metrics.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\calibration_metrics_tf1_test.py to calibration_metrics_tf1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\coco_evaluation.py to coco_evaluation.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\coco_evaluation_test.py to coco_evaluation_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\coco_tools.py to coco_tools.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\coco_tools_test.py to coco_tools_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\io_utils.py to io_utils.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\lvis_evaluation.py to lvis_evaluation.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\lvis_evaluation_test.py to lvis_evaluation_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\lvis_tools.py to lvis_tools.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\lvis_tools_test.py to lvis_tools_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\offline_eval_map_corloc.py to offline_eval_map_corloc.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\offline_eval_map_corloc_test.py to offline_eval_map_corloc_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\oid_challenge_evaluation.py to oid_challenge_evaluation.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\oid_challenge_evaluation_utils.py to oid_challenge_evaluation_utils.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\oid_challenge_evaluation_utils_test.py to oid_challenge_evaluation_utils_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\oid_vrd_challenge_evaluation.py to oid_vrd_challenge_evaluation.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\oid_vrd_challenge_evaluation_utils.py to oid_vrd_challenge_evaluation_utils.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\oid_vrd_challenge_evaluation_utils_test.py to oid_vrd_challenge_evaluation_utils_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\tf_example_parser.py to tf_example_parser.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\tf_example_parser_test.py to tf_example_parser_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\__init__.py to __init__.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\bidirectional_feature_pyramid_generators.py to bidirectional_feature_pyramid_generators.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\bidirectional_feature_pyramid_generators_tf2_test.py to bidirectional_feature_pyramid_generators_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\center_net_hourglass_feature_extractor.py to center_net_hourglass_feature_extractor.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\center_net_hourglass_feature_extractor_tf2_test.py to center_net_hourglass_feature_extractor_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\center_net_mobilenet_v2_feature_extractor.py to center_net_mobilenet_v2_feature_extractor.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\center_net_mobilenet_v2_feature_extractor_tf2_test.py to center_net_mobilenet_v2_feature_extractor_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\center_net_mobilenet_v2_fpn_feature_extractor.py to center_net_mobilenet_v2_fpn_feature_extractor.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\center_net_mobilenet_v2_fpn_feature_extractor_tf2_test.py to center_net_mobilenet_v2_fpn_feature_extractor_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\center_net_resnet_feature_extractor.py to center_net_resnet_feature_extractor.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\center_net_resnet_feature_extractor_tf2_test.py to center_net_resnet_feature_extractor_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\center_net_resnet_v1_fpn_feature_extractor.py to center_net_resnet_v1_fpn_feature_extractor.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\center_net_resnet_v1_fpn_feature_extractor_tf2_test.py to center_net_resnet_v1_fpn_feature_extractor_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\embedded_ssd_mobilenet_v1_feature_extractor.py to embedded_ssd_mobilenet_v1_feature_extractor.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\embedded_ssd_mobilenet_v1_feature_extractor_tf1_test.py to embedded_ssd_mobilenet_v1_feature_extractor_tf1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\faster_rcnn_inception_resnet_v2_feature_extractor.py to faster_rcnn_inception_resnet_v2_feature_extractor.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\faster_rcnn_inception_resnet_v2_feature_extractor_tf1_test.py to faster_rcnn_inception_resnet_v2_feature_extractor_tf1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\faster_rcnn_inception_resnet_v2_keras_feature_extractor.py to faster_rcnn_inception_resnet_v2_keras_feature_extractor.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\faster_rcnn_inception_resnet_v2_keras_feature_extractor_tf2_test.py to faster_rcnn_inception_resnet_v2_keras_feature_extractor_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\faster_rcnn_inception_v2_feature_extractor.py to faster_rcnn_inception_v2_feature_extractor.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\faster_rcnn_inception_v2_feature_extractor_tf1_test.py to faster_rcnn_inception_v2_feature_extractor_tf1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\faster_rcnn_mobilenet_v1_feature_extractor.py to faster_rcnn_mobilenet_v1_feature_extractor.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\faster_rcnn_mobilenet_v1_feature_extractor_tf1_test.py to faster_rcnn_mobilenet_v1_feature_extractor_tf1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\faster_rcnn_nas_feature_extractor.py to faster_rcnn_nas_feature_extractor.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\faster_rcnn_nas_feature_extractor_tf1_test.py to faster_rcnn_nas_feature_extractor_tf1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\faster_rcnn_pnas_feature_extractor.py to faster_rcnn_pnas_feature_extractor.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\faster_rcnn_pnas_feature_extractor_tf1_test.py to faster_rcnn_pnas_feature_extractor_tf1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\faster_rcnn_resnet_keras_feature_extractor.py to faster_rcnn_resnet_keras_feature_extractor.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\faster_rcnn_resnet_keras_feature_extractor_tf2_test.py to faster_rcnn_resnet_keras_feature_extractor_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\faster_rcnn_resnet_v1_feature_extractor.py to faster_rcnn_resnet_v1_feature_extractor.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\faster_rcnn_resnet_v1_feature_extractor_tf1_test.py to faster_rcnn_resnet_v1_feature_extractor_tf1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\faster_rcnn_resnet_v1_fpn_keras_feature_extractor.py to faster_rcnn_resnet_v1_fpn_keras_feature_extractor.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\faster_rcnn_resnet_v1_fpn_keras_feature_extractor_tf2_test.py to faster_rcnn_resnet_v1_fpn_keras_feature_extractor_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\feature_map_generators.py to feature_map_generators.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\feature_map_generators_test.py to feature_map_generators_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\keras_models\convert_keras_models.py to convert_keras_models.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\keras_models\hourglass_network.py to hourglass_network.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\keras_models\hourglass_network_tf2_test.py to hourglass_network_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\keras_models\inception_resnet_v2.py to inception_resnet_v2.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\keras_models\inception_resnet_v2_tf2_test.py to inception_resnet_v2_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\keras_models\mobilenet_v1.py to mobilenet_v1.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\keras_models\mobilenet_v1_tf2_test.py to mobilenet_v1_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\keras_models\mobilenet_v2.py to mobilenet_v2.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\keras_models\mobilenet_v2_tf2_test.py to mobilenet_v2_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\keras_models\model_utils.py to model_utils.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\keras_models\nonlocal_block.py to nonlocal_block.cpython-39.pyc
# ...
# byte-compiling c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\np_box_mask_list.py to np_box_mask_list.cpython-39.pyc
# byte-compiling c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\np_box_mask_list_ops.py to np_box_mask_list_ops.cpython-39.pyc
# byte-compiling c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\np_box_mask_list_ops_test.py to np_box_mask_list_ops_test.cpython-39.pyc
# byte-compiling c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\np_box_mask_list_test.py to np_box_mask_list_test.cpython-39.pyc
# byte-compiling c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\np_box_ops.py to np_box_ops.cpython-39.pyc
# byte-compiling c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\np_box_ops_test.py to np_box_ops_test.cpython-39.pyc
# byte-compiling c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\np_mask_ops.py to np_mask_ops.cpython-39.pyc
# byte-compiling c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\np_mask_ops_test.py to np_mask_ops_test.cpython-39.pyc
# byte-compiling c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\object_detection_evaluation.py to object_detection_evaluation.cpython-39.pyc
# byte-compiling c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\object_detection_evaluation_test.py to object_detection_evaluation_test.cpython-39.pyc
# byte-compiling c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\ops.py to ops.cpython-39.pyc
# byte-compiling c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\ops_test.py to ops_test.cpython-39.pyc
# byte-compiling c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\patch_ops.py to patch_ops.cpython-39.pyc
# byte-compiling c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\patch_ops_test.py to patch_ops_test.cpython-39.pyc
# byte-compiling c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\per_image_evaluation.py to per_image_evaluation.cpython-39.pyc
# byte-compiling c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\per_image_evaluation_test.py to per_image_evaluation_test.cpython-39.pyc
# byte-compiling c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\per_image_vrd_evaluation.py to per_image_vrd_evaluation.cpython-39.pyc
# byte-compiling c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\per_image_vrd_evaluation_test.py to per_image_vrd_evaluation_test.cpython-39.pyc
# byte-compiling c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\shape_utils.py to shape_utils.cpython-39.pyc
# byte-compiling c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\shape_utils_test.py to shape_utils_test.cpython-39.pyc
# byte-compiling c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\spatial_transform_ops.py to spatial_transform_ops.cpython-39.pyc
# byte-compiling c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\spatial_transform_ops_test.py to spatial_transform_ops_test.cpython-39.pyc
# byte-compiling c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\static_shape.py to static_shape.cpython-39.pyc
# byte-compiling c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\static_shape_test.py to static_shape_test.cpython-39.pyc
# byte-compiling c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\target_assigner_utils.py to target_assigner_utils.cpython-39.pyc
# byte-compiling c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\target_assigner_utils_test.py to target_assigner_utils_test.cpython-39.pyc
# byte-compiling c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\test_case.py to test_case.cpython-39.pyc
# byte-compiling c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\test_case_test.py to test_case_test.cpython-39.pyc
# byte-compiling c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\test_utils.py to test_utils.cpython-39.pyc
# byte-compiling c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\test_utils_test.py to test_utils_test.cpython-39.pyc
# byte-compiling c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\tf_version.py to tf_version.cpython-39.pyc
# byte-compiling c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\variables_helper.py to variables_helper.cpython-39.pyc
# byte-compiling c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\variables_helper_tf1_test.py to variables_helper_tf1_test.cpython-39.pyc
# byte-compiling c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\visualization_utils.py to visualization_utils.cpython-39.pyc
# byte-compiling c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\visualization_utils_test.py to visualization_utils_test.cpython-39.pyc
# byte-compiling c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\vrd_evaluation.py to vrd_evaluation.cpython-39.pyc
# byte-compiling c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\vrd_evaluation_test.py to vrd_evaluation_test.cpython-39.pyc
# byte-compiling c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\object_detection-0.1-py3.9.egg\preprocessing\__init__.py to __init__.cpython-39.pyc
# byte-compiling c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\object_detection-0.1-py3.9.egg\preprocessing\cifarnet_preprocessing.py to cifarnet_preprocessing.cpython-39.pyc
# byte-compiling c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\object_detection-0.1-py3.9.egg\preprocessing\inception_preprocessing.py to inception_preprocessing.cpython-39.pyc
# byte-compiling c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\object_detection-0.1-py3.9.egg\preprocessing\lenet_preprocessing.py to lenet_preprocessing.cpython-39.pyc
# byte-compiling c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\object_detection-0.1-py3.9.egg\preprocessing\preprocessing_factory.py to preprocessing_factory.cpython-39.pyc
# byte-compiling c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\object_detection-0.1-py3.9.egg\preprocessing\vgg_preprocessing.py to vgg_preprocessing.cpython-39.pyc
# Adding object-detection 0.1 to easy-install.pth file
#
# Installed c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\object_detection-0.1-py3.9.egg
# Processing dependencies for object-detection==0.1
# Searching for keras
# Reading https://pypi.org/simple/keras/
# Downloading https://files.pythonhosted.org/packages/2e/7c/df6f389ee9a9acac0a3a84e27f755fc1f62146b9dab436267562be5924bd/keras-2.8.0rc1-py2.py3-none-any.whl#sha256=ce86dd1133bc9a8b1cafab48013c28f8651e5093e9429209b0f8bb7acf1310ac
# Best match: keras 2.8.0rc1
# Processing keras-2.8.0rc1-py2.py3-none-any.whl
# Installing keras-2.8.0rc1-py2.py3-none-any.whl to c:\users\xavie\documents\github\coursework\tfod\lib\site-packages
# Adding keras 2.8.0rc1 to easy-install.pth file
#
# Installed c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\keras-2.8.0rc1-py3.9.egg
# Searching for tensorflow_io
# Reading https://pypi.org/simple/tensorflow_io/
# Downloading https://files.pythonhosted.org/packages/ff/a3/5e240a9297920ae4471ba4e84453018084f8b08d8d73cec3a79fa4a15724/tensorflow_io-0.23.1-cp39-cp39-win_amd64.whl#sha256=0c7e3814aa3d287ebc4b0e5ea852a21af2f5e867e239636c29ab979eb5b7ba31
# Best match: tensorflow-io 0.23.1
# Processing tensorflow_io-0.23.1-cp39-cp39-win_amd64.whl
# Installing tensorflow_io-0.23.1-cp39-cp39-win_amd64.whl to c:\users\xavie\documents\github\coursework\tfod\lib\site-packages
# Adding tensorflow-io 0.23.1 to easy-install.pth file
#
# Installed c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\tensorflow_io-0.23.1-py3.9-win-amd64.egg
# Searching for tf-models-official>=2.5.1
# Reading https://pypi.org/simple/tf-models-official/
# Downloading https://files.pythonhosted.org/packages/ce/e2/25507423e250d6987351471cf54bcf170c93465a1199d2764162e1bde396/tf_models_official-2.7.0-py2.py3-none-any.whl#sha256=152bc7dbeac4e6c4852db350b4cdfcf90544c4c70edd38af57e48ea823db0b83
# Best match: tf-models-official 2.7.0
# Processing tf_models_official-2.7.0-py2.py3-none-any.whl
# Installing tf_models_official-2.7.0-py2.py3-none-any.whl to c:\users\xavie\documents\github\coursework\tfod\lib\site-packages
# Adding tf-models-official 2.7.0 to easy-install.pth file
#
# Installed c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\tf_models_official-2.7.0-py3.9.egg
# Searching for pandas
# Reading https://pypi.org/simple/pandas/
# Downloading https://files.pythonhosted.org/packages/53/1a/1a2c484259c16ec132c4b3694a59b9562609b6955e3f9a7dad8af066a021/pandas-1.4.0-cp39-cp39-win_amd64.whl#sha256=23c04dab11f3c6359cfa7afa83d3d054a8f8c283d773451184d98119ef54da97
# Best match: pandas 1.4.0
# Processing pandas-1.4.0-cp39-cp39-win_amd64.whl
# Installing pandas-1.4.0-cp39-cp39-win_amd64.whl to c:\users\xavie\documents\github\coursework\tfod\lib\site-packages
# Adding pandas 1.4.0 to easy-install.pth file
#
# Installed c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\pandas-1.4.0-py3.9-win-amd64.egg
# Searching for scipy
# Reading https://pypi.org/simple/scipy/
# Downloading https://files.pythonhosted.org/packages/b5/75/199155f07cb3549ac6c3d87337659bdb51c2f334a7816b22c8de7f43c6be/scipy-1.8.0rc3-cp39-cp39-win_amd64.whl#sha256=d7f1c8513955cbcb6b8afd11a22d3536290456e1b30b3e6b4e93aaf1deed790d
# Best match: scipy 1.8.0rc3
# Processing scipy-1.8.0rc3-cp39-cp39-win_amd64.whl
# Installing scipy-1.8.0rc3-cp39-cp39-win_amd64.whl to c:\users\xavie\documents\github\coursework\tfod\lib\site-packages
# Adding scipy 1.8.0rc3 to easy-install.pth file
#
# Installed c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\scipy-1.8.0rc3-py3.9-win-amd64.egg
# Searching for lvis
# Reading https://pypi.org/simple/lvis/
# Downloading https://files.pythonhosted.org/packages/72/b6/1992240ab48310b5360bfdd1d53163f43bb97d90dc5dc723c67d41c38e78/lvis-0.5.3-py3-none-any.whl#sha256=4f07153330df342b3161fafb46641ce7c02864113a8ddf0d6ffab6b02407bef0
# Best match: lvis 0.5.3
# Processing lvis-0.5.3-py3-none-any.whl
# Installing lvis-0.5.3-py3-none-any.whl to c:\users\xavie\documents\github\coursework\tfod\lib\site-packages
# Adding lvis 0.5.3 to easy-install.pth file
#
# Installed c:\users\xavie\documents\github\coursework\tfod\lib\site-packages\lvis-0.5.3-py3.9.egg
# Searching for pycocotools
# Reading https://pypi.org/simple/pycocotools/
# Downloading https://files.pythonhosted.org/packages/75/5c/ac61ea715d7a89ecc31c090753bde28810238225ca8b71778dfe3e6a68bc/pycocotools-2.0.4.tar.gz#sha256=2ab586aa389b9657b6d73c2b9a827a3681f8d00f36490c2e8ab05902e3fd9e93
# Best match: pycocotools 2.0.4
# Processing pycocotools-2.0.4.tar.gz
# Writing C:\Users\xavie\AppData\Local\Temp\easy_install-cenxtwp1\pycocotools-2.0.4\setup.cfg
# Running pycocotools-2.0.4\setup.py -q bdist_egg --dist-dir C:\Users\xavie\AppData\Local\Temp\easy_install-cenxtwp1\pycocotools-2.0.4\egg-dist-tmp-nftvzacf
# Obtaining file:///C:/Users/xavie/Documents/GitHub/coursework/Tensorflow/models/research/slim
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: six in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from slim==0.1) (1.16.0)
# Collecting tf-slim>=1.1
#   Using cached tf_slim-1.1.0-py2.py3-none-any.whl (352 kB)
# Collecting absl-py>=0.2.2
#   Using cached absl_py-1.0.0-py3-none-any.whl (126 kB)
# Installing collected packages: absl-py, tf-slim, slim
#   Running setup.py develop for slim
# Successfully installed absl-py-1.0.0 slim-0.1 tf-slim-1.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# object-detection 0.1 requires apache-beam, which is not installed.
# object-detection 0.1 requires avro-python3, which is not installed.
# object-detection 0.1 requires contextlib2, which is not installed.
# object-detection 0.1 requires Cython, which is not installed.
# object-detection 0.1 requires lxml, which is not installed.
# object-detection 0.1 requires matplotlib, which is not installed.
# object-detection 0.1 requires pillow, which is not installed.
# object-detection 0.1 requires pycocotools, which is not installed.
# tf-models-official 2.7.0 requires Cython, which is not installed.
# tf-models-official 2.7.0 requires gin-config, which is not installed.
# tf-models-official 2.7.0 requires google-api-python-client>=1.6.7, which is not installed.
# tf-models-official 2.7.0 requires kaggle>=1.3.9, which is not installed.
# tf-models-official 2.7.0 requires matplotlib, which is not installed.
# tf-models-official 2.7.0 requires numpy>=1.15.4, which is not installed.
# tf-models-official 2.7.0 requires oauth2client, which is not installed.
# tf-models-official 2.7.0 requires opencv-python-headless, which is not installed.
# tf-models-official 2.7.0 requires Pillow, which is not installed.
# tf-models-official 2.7.0 requires psutil>=5.4.3, which is not installed.
# tf-models-official 2.7.0 requires py-cpuinfo>=3.3.0, which is not installed.
# tf-models-official 2.7.0 requires pycocotools, which is not installed.
# tf-models-official 2.7.0 requires pyyaml>=5.1, which is not installed.
# tf-models-official 2.7.0 requires sacrebleu, which is not installed.
# tf-models-official 2.7.0 requires sentencepiece, which is not installed.
# tf-models-official 2.7.0 requires seqeval, which is not installed.
# tf-models-official 2.7.0 requires tensorflow>=2.7.0, which is not installed.
# tf-models-official 2.7.0 requires tensorflow-addons, which is not installed.
# tf-models-official 2.7.0 requires tensorflow-datasets, which is not installed.
# tf-models-official 2.7.0 requires tensorflow-hub>=0.6.0, which is not installed.
# tf-models-official 2.7.0 requires tensorflow-model-optimization>=0.4.1, which is not installed.
# tf-models-official 2.7.0 requires tensorflow-text>=2.7.0, which is not installed.

# %%
VERIFICATION_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'builders', 'model_builder_tf2_test.py')
# Verify Installation
# !python {VERIFICATION_SCRIPT}
# Out:
# Running tests under Python 3.9.10: C:\Users\xavie\Documents\GitHub\coursework\tfod\Scripts\python.exe
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_deepmac
# 2022-01-25 18:33:42.392113: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-01-25 18:33:42.865721: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3987 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1660 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
# C:\Users\xavie\Documents\GitHub\coursework\tfod\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\builders\model_builder.py:1100: DeprecationWarning: The 'warn' function is deprecated, use 'warning' instead
#   logging.warn(('Building experimental DeepMAC meta-arch.'
# W0125 18:33:43.105975  1400 model_builder.py:1100] Building experimental DeepMAC meta-arch. Some features may be omitted.
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 0.86s
# I0125 18:33:43.245007  1400 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 0.86s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_deepmac
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 0.83s
# I0125 18:33:44.073194  1400 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 0.83s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.15s
# I0125 18:33:44.223977  1400 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.15s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.14s
# I0125 18:33:44.363013  1400 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.14s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 1.04s
# I0125 18:33:45.401128  1400 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 1.04s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# [ RUN      ] ModelBuilderTF2Test.test_create_experimental_model
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# I0125 18:33:45.402128  1400 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# [       OK ] ModelBuilderTF2Test.test_create_experimental_model
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.01s
# I0125 18:33:45.415131  1400 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.01s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.01s
# I0125 18:33:45.423133  1400 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.01s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.01s
# I0125 18:33:45.432135  1400 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.01s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.06s
# I0125 18:33:45.491148  1400 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.06s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.05s
# I0125 18:33:45.542159  1400 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.05s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.05s
# I0125 18:33:45.596172  1400 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.05s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.05s
# I0125 18:33:45.649183  1400 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.05s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.05s
# I0125 18:33:45.700195  1400 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.05s
# [       OK ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.02s
# I0125 18:33:45.716199  1400 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# I0125 18:33:45.812220  1400 ssd_efficientnet_bifpn_feature_extractor.py:145] EfficientDet EfficientNet backbone version: efficientnet-b0
# I0125 18:33:45.812220  1400 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 64
# I0125 18:33:45.812220  1400 ssd_efficientnet_bifpn_feature_extractor.py:148] EfficientDet BiFPN num iterations: 3
# I0125 18:33:45.813221  1400 efficientnet_model.py:147] round_filter input=32 output=32
# I0125 18:33:45.823223  1400 efficientnet_model.py:147] round_filter input=32 output=32
# I0125 18:33:45.823223  1400 efficientnet_model.py:147] round_filter input=16 output=16
# I0125 18:33:45.857231  1400 efficientnet_model.py:147] round_filter input=16 output=16
# I0125 18:33:45.857231  1400 efficientnet_model.py:147] round_filter input=24 output=24
# I0125 18:33:45.940249  1400 efficientnet_model.py:147] round_filter input=24 output=24
# I0125 18:33:45.940249  1400 efficientnet_model.py:147] round_filter input=40 output=40
# I0125 18:33:46.027269  1400 efficientnet_model.py:147] round_filter input=40 output=40
# I0125 18:33:46.027269  1400 efficientnet_model.py:147] round_filter input=80 output=80
# I0125 18:33:46.155298  1400 efficientnet_model.py:147] round_filter input=80 output=80
# I0125 18:33:46.155298  1400 efficientnet_model.py:147] round_filter input=112 output=112
# I0125 18:33:46.289328  1400 efficientnet_model.py:147] round_filter input=112 output=112
# I0125 18:33:46.289328  1400 efficientnet_model.py:147] round_filter input=192 output=192
# I0125 18:33:46.576392  1400 efficientnet_model.py:147] round_filter input=192 output=192
# I0125 18:33:46.576392  1400 efficientnet_model.py:147] round_filter input=320 output=320
# I0125 18:33:46.616402  1400 efficientnet_model.py:147] round_filter input=1280 output=1280
# I0125 18:33:46.633406  1400 efficientnet_model.py:457] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.0, resolution=224, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0125 18:33:46.664413  1400 ssd_efficientnet_bifpn_feature_extractor.py:145] EfficientDet EfficientNet backbone version: efficientnet-b1
# I0125 18:33:46.664413  1400 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 88
# I0125 18:33:46.665413  1400 ssd_efficientnet_bifpn_feature_extractor.py:148] EfficientDet BiFPN num iterations: 4
# I0125 18:33:46.665413  1400 efficientnet_model.py:147] round_filter input=32 output=32
# I0125 18:33:46.674415  1400 efficientnet_model.py:147] round_filter input=32 output=32
# I0125 18:33:46.674415  1400 efficientnet_model.py:147] round_filter input=16 output=16
# I0125 18:33:46.736429  1400 efficientnet_model.py:147] round_filter input=16 output=16
# I0125 18:33:46.737429  1400 efficientnet_model.py:147] round_filter input=24 output=24
# I0125 18:33:46.857456  1400 efficientnet_model.py:147] round_filter input=24 output=24
# I0125 18:33:46.857456  1400 efficientnet_model.py:147] round_filter input=40 output=40
# I0125 18:33:46.981484  1400 efficientnet_model.py:147] round_filter input=40 output=40
# I0125 18:33:46.981484  1400 efficientnet_model.py:147] round_filter input=80 output=80
# I0125 18:33:47.144521  1400 efficientnet_model.py:147] round_filter input=80 output=80
# I0125 18:33:47.144521  1400 efficientnet_model.py:147] round_filter input=112 output=112
# I0125 18:33:47.306557  1400 efficientnet_model.py:147] round_filter input=112 output=112
# I0125 18:33:47.306557  1400 efficientnet_model.py:147] round_filter input=192 output=192
# I0125 18:33:47.521605  1400 efficientnet_model.py:147] round_filter input=192 output=192
# I0125 18:33:47.521605  1400 efficientnet_model.py:147] round_filter input=320 output=320
# I0125 18:33:47.606625  1400 efficientnet_model.py:147] round_filter input=1280 output=1280
# I0125 18:33:47.621628  1400 efficientnet_model.py:457] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.1, resolution=240, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0125 18:33:47.656636  1400 ssd_efficientnet_bifpn_feature_extractor.py:145] EfficientDet EfficientNet backbone version: efficientnet-b2
# I0125 18:33:47.656636  1400 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 112
# I0125 18:33:47.657637  1400 ssd_efficientnet_bifpn_feature_extractor.py:148] EfficientDet BiFPN num iterations: 5
# I0125 18:33:47.657637  1400 efficientnet_model.py:147] round_filter input=32 output=32
# I0125 18:33:47.666639  1400 efficientnet_model.py:147] round_filter input=32 output=32
# I0125 18:33:47.666639  1400 efficientnet_model.py:147] round_filter input=16 output=16
# I0125 18:33:47.729652  1400 efficientnet_model.py:147] round_filter input=16 output=16
# I0125 18:33:47.729652  1400 efficientnet_model.py:147] round_filter input=24 output=24
# I0125 18:33:47.851680  1400 efficientnet_model.py:147] round_filter input=24 output=24
# I0125 18:33:47.851680  1400 efficientnet_model.py:147] round_filter input=40 output=48
# I0125 18:33:47.975708  1400 efficientnet_model.py:147] round_filter input=40 output=48
# I0125 18:33:47.975708  1400 efficientnet_model.py:147] round_filter input=80 output=88
# I0125 18:33:48.145746  1400 efficientnet_model.py:147] round_filter input=80 output=88
# I0125 18:33:48.145746  1400 efficientnet_model.py:147] round_filter input=112 output=120
# I0125 18:33:48.321786  1400 efficientnet_model.py:147] round_filter input=112 output=120
# I0125 18:33:48.321786  1400 efficientnet_model.py:147] round_filter input=192 output=208
# I0125 18:33:48.688869  1400 efficientnet_model.py:147] round_filter input=192 output=208
# I0125 18:33:48.688869  1400 efficientnet_model.py:147] round_filter input=320 output=352
# I0125 18:33:48.775888  1400 efficientnet_model.py:147] round_filter input=1280 output=1408
# I0125 18:33:48.796893  1400 efficientnet_model.py:457] Building model efficientnet with params ModelConfig(width_coefficient=1.1, depth_coefficient=1.2, resolution=260, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0125 18:33:48.837903  1400 ssd_efficientnet_bifpn_feature_extractor.py:145] EfficientDet EfficientNet backbone version: efficientnet-b3
# I0125 18:33:48.837903  1400 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 160
# I0125 18:33:48.837903  1400 ssd_efficientnet_bifpn_feature_extractor.py:148] EfficientDet BiFPN num iterations: 6
# I0125 18:33:48.838903  1400 efficientnet_model.py:147] round_filter input=32 output=40
# I0125 18:33:48.848905  1400 efficientnet_model.py:147] round_filter input=32 output=40
# I0125 18:33:48.848905  1400 efficientnet_model.py:147] round_filter input=16 output=24
# I0125 18:33:48.915920  1400 efficientnet_model.py:147] round_filter input=16 output=24
# I0125 18:33:48.915920  1400 efficientnet_model.py:147] round_filter input=24 output=32
# I0125 18:33:49.053419  1400 efficientnet_model.py:147] round_filter input=24 output=32
# I0125 18:33:49.053419  1400 efficientnet_model.py:147] round_filter input=40 output=48
# I0125 18:33:49.189450  1400 efficientnet_model.py:147] round_filter input=40 output=48
# I0125 18:33:49.189450  1400 efficientnet_model.py:147] round_filter input=80 output=96
# I0125 18:33:49.411501  1400 efficientnet_model.py:147] round_filter input=80 output=96
# I0125 18:33:49.411501  1400 efficientnet_model.py:147] round_filter input=112 output=136
# I0125 18:33:49.640552  1400 efficientnet_model.py:147] round_filter input=112 output=136
# I0125 18:33:49.640552  1400 efficientnet_model.py:147] round_filter input=192 output=232
# I0125 18:33:49.913613  1400 efficientnet_model.py:147] round_filter input=192 output=232
# I0125 18:33:49.913613  1400 efficientnet_model.py:147] round_filter input=320 output=384
# I0125 18:33:50.000632  1400 efficientnet_model.py:147] round_filter input=1280 output=1536
# I0125 18:33:50.017637  1400 efficientnet_model.py:457] Building model efficientnet with params ModelConfig(width_coefficient=1.2, depth_coefficient=1.4, resolution=300, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0125 18:33:50.063647  1400 ssd_efficientnet_bifpn_feature_extractor.py:145] EfficientDet EfficientNet backbone version: efficientnet-b4
# I0125 18:33:50.063647  1400 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 224
# I0125 18:33:50.063647  1400 ssd_efficientnet_bifpn_feature_extractor.py:148] EfficientDet BiFPN num iterations: 7
# I0125 18:33:50.064648  1400 efficientnet_model.py:147] round_filter input=32 output=48
# I0125 18:33:50.073649  1400 efficientnet_model.py:147] round_filter input=32 output=48
# I0125 18:33:50.073649  1400 efficientnet_model.py:147] round_filter input=16 output=24
# I0125 18:33:50.143665  1400 efficientnet_model.py:147] round_filter input=16 output=24
# I0125 18:33:50.143665  1400 efficientnet_model.py:147] round_filter input=24 output=32
# I0125 18:33:50.320705  1400 efficientnet_model.py:147] round_filter input=24 output=32
# I0125 18:33:50.320705  1400 efficientnet_model.py:147] round_filter input=40 output=56
# I0125 18:33:50.518750  1400 efficientnet_model.py:147] round_filter input=40 output=56
# I0125 18:33:50.519750  1400 efficientnet_model.py:147] round_filter input=80 output=112
# I0125 18:33:50.799813  1400 efficientnet_model.py:147] round_filter input=80 output=112
# I0125 18:33:50.799813  1400 efficientnet_model.py:147] round_filter input=112 output=160
# I0125 18:33:51.310693  1400 efficientnet_model.py:147] round_filter input=112 output=160
# I0125 18:33:51.311695  1400 efficientnet_model.py:147] round_filter input=192 output=272
# I0125 18:33:51.779558  1400 efficientnet_model.py:147] round_filter input=192 output=272
# I0125 18:33:51.779558  1400 efficientnet_model.py:147] round_filter input=320 output=448
# I0125 18:33:51.865577  1400 efficientnet_model.py:147] round_filter input=1280 output=1792
# I0125 18:33:51.881581  1400 efficientnet_model.py:457] Building model efficientnet with params ModelConfig(width_coefficient=1.4, depth_coefficient=1.8, resolution=380, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0125 18:33:51.926591  1400 ssd_efficientnet_bifpn_feature_extractor.py:145] EfficientDet EfficientNet backbone version: efficientnet-b5
# I0125 18:33:51.927590  1400 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 288
# I0125 18:33:51.927590  1400 ssd_efficientnet_bifpn_feature_extractor.py:148] EfficientDet BiFPN num iterations: 7
# I0125 18:33:51.928591  1400 efficientnet_model.py:147] round_filter input=32 output=48
# I0125 18:33:51.937594  1400 efficientnet_model.py:147] round_filter input=32 output=48
# I0125 18:33:51.937594  1400 efficientnet_model.py:147] round_filter input=16 output=24
# I0125 18:33:52.041617  1400 efficientnet_model.py:147] round_filter input=16 output=24
# I0125 18:33:52.041617  1400 efficientnet_model.py:147] round_filter input=24 output=40
# I0125 18:33:52.266668  1400 efficientnet_model.py:147] round_filter input=24 output=40
# I0125 18:33:52.266668  1400 efficientnet_model.py:147] round_filter input=40 output=64
# I0125 18:33:52.498720  1400 efficientnet_model.py:147] round_filter input=40 output=64
# I0125 18:33:52.498720  1400 efficientnet_model.py:147] round_filter input=80 output=128
# I0125 18:33:52.830796  1400 efficientnet_model.py:147] round_filter input=80 output=128
# I0125 18:33:52.830796  1400 efficientnet_model.py:147] round_filter input=112 output=176
# I0125 18:33:53.144865  1400 efficientnet_model.py:147] round_filter input=112 output=176
# I0125 18:33:53.144865  1400 efficientnet_model.py:147] round_filter input=192 output=304
# I0125 18:33:53.529952  1400 efficientnet_model.py:147] round_filter input=192 output=304
# I0125 18:33:53.529952  1400 efficientnet_model.py:147] round_filter input=320 output=512
# I0125 18:33:53.660982  1400 efficientnet_model.py:147] round_filter input=1280 output=2048
# I0125 18:33:53.678986  1400 efficientnet_model.py:457] Building model efficientnet with params ModelConfig(width_coefficient=1.6, depth_coefficient=2.2, resolution=456, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0125 18:33:53.731998  1400 ssd_efficientnet_bifpn_feature_extractor.py:145] EfficientDet EfficientNet backbone version: efficientnet-b6
# I0125 18:33:53.731998  1400 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 384
# I0125 18:33:53.731998  1400 ssd_efficientnet_bifpn_feature_extractor.py:148] EfficientDet BiFPN num iterations: 8
# I0125 18:33:53.732998  1400 efficientnet_model.py:147] round_filter input=32 output=56
# I0125 18:33:53.742000  1400 efficientnet_model.py:147] round_filter input=32 output=56
# I0125 18:33:53.742000  1400 efficientnet_model.py:147] round_filter input=16 output=32
# I0125 18:33:54.063072  1400 efficientnet_model.py:147] round_filter input=16 output=32
# I0125 18:33:54.063072  1400 efficientnet_model.py:147] round_filter input=24 output=40
# I0125 18:33:54.343136  1400 efficientnet_model.py:147] round_filter input=24 output=40
# I0125 18:33:54.343136  1400 efficientnet_model.py:147] round_filter input=40 output=72
# I0125 18:33:54.618198  1400 efficientnet_model.py:147] round_filter input=40 output=72
# I0125 18:33:54.618198  1400 efficientnet_model.py:147] round_filter input=80 output=144
# I0125 18:33:54.984280  1400 efficientnet_model.py:147] round_filter input=80 output=144
# I0125 18:33:54.984280  1400 efficientnet_model.py:147] round_filter input=112 output=200
# I0125 18:33:55.352364  1400 efficientnet_model.py:147] round_filter input=112 output=200
# I0125 18:33:55.352364  1400 efficientnet_model.py:147] round_filter input=192 output=344
# I0125 18:33:55.852477  1400 efficientnet_model.py:147] round_filter input=192 output=344
# I0125 18:33:55.852477  1400 efficientnet_model.py:147] round_filter input=320 output=576
# I0125 18:33:55.991595  1400 efficientnet_model.py:147] round_filter input=1280 output=2304
# I0125 18:33:56.008599  1400 efficientnet_model.py:457] Building model efficientnet with params ModelConfig(width_coefficient=1.8, depth_coefficient=2.6, resolution=528, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0125 18:33:56.072614  1400 ssd_efficientnet_bifpn_feature_extractor.py:145] EfficientDet EfficientNet backbone version: efficientnet-b7
# I0125 18:33:56.072614  1400 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 384
# I0125 18:33:56.072614  1400 ssd_efficientnet_bifpn_feature_extractor.py:148] EfficientDet BiFPN num iterations: 8
# I0125 18:33:56.073614  1400 efficientnet_model.py:147] round_filter input=32 output=64
# I0125 18:33:56.082616  1400 efficientnet_model.py:147] round_filter input=32 output=64
# I0125 18:33:56.082616  1400 efficientnet_model.py:147] round_filter input=16 output=32
# I0125 18:33:56.227648  1400 efficientnet_model.py:147] round_filter input=16 output=32
# I0125 18:33:56.227648  1400 efficientnet_model.py:147] round_filter input=24 output=48
# I0125 18:33:56.540719  1400 efficientnet_model.py:147] round_filter input=24 output=48
# I0125 18:33:56.540719  1400 efficientnet_model.py:147] round_filter input=40 output=80
# I0125 18:33:57.054835  1400 efficientnet_model.py:147] round_filter input=40 output=80
# I0125 18:33:57.054835  1400 efficientnet_model.py:147] round_filter input=80 output=160
# I0125 18:33:57.473929  1400 efficientnet_model.py:147] round_filter input=80 output=160
# I0125 18:33:57.473929  1400 efficientnet_model.py:147] round_filter input=112 output=224
# I0125 18:33:57.928032  1400 efficientnet_model.py:147] round_filter input=112 output=224
# I0125 18:33:57.928032  1400 efficientnet_model.py:147] round_filter input=192 output=384
# I0125 18:33:58.489159  1400 efficientnet_model.py:147] round_filter input=192 output=384
# I0125 18:33:58.489159  1400 efficientnet_model.py:147] round_filter input=320 output=640
# I0125 18:33:58.660633  1400 efficientnet_model.py:147] round_filter input=1280 output=2560
# I0125 18:33:58.683638  1400 efficientnet_model.py:457] Building model efficientnet with params ModelConfig(width_coefficient=2.0, depth_coefficient=3.1, resolution=600, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 13.04s
# I0125 18:33:58.756655  1400 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 13.04s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# [ RUN      ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# I0125 18:33:58.761656  1400 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# [ RUN      ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# I0125 18:33:58.762656  1400 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# [ RUN      ] ModelBuilderTF2Test.test_invalid_model_config_proto
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# I0125 18:33:58.762656  1400 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_model_config_proto
# [ RUN      ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# I0125 18:33:58.763656  1400 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# [ RUN      ] ModelBuilderTF2Test.test_session
# [  SKIPPED ] ModelBuilderTF2Test.test_session
# [ RUN      ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# I0125 18:33:58.763656  1400 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# [ RUN      ] ModelBuilderTF2Test.test_unknown_meta_architecture
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# I0125 18:33:58.764657  1400 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_meta_architecture
# [ RUN      ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# I0125 18:33:58.764657  1400 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# ----------------------------------------------------------------------
# Ran 24 tests in 16.377s
#
# OK (skipped=1)

# %%
# !pip install pyyaml
# Out:
# Collecting pyyaml
#   Using cached PyYAML-6.0-cp39-cp39-win_amd64.whl (151 kB)
# Installing collected packages: pyyaml
# Successfully installed pyyaml-6.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tf-models-official 2.7.0 requires Cython, which is not installed.
# tf-models-official 2.7.0 requires gin-config, which is not installed.
# tf-models-official 2.7.0 requires google-api-python-client>=1.6.7, which is not installed.
# tf-models-official 2.7.0 requires kaggle>=1.3.9, which is not installed.
# tf-models-official 2.7.0 requires oauth2client, which is not installed.
# tf-models-official 2.7.0 requires opencv-python-headless, which is not installed.
# tf-models-official 2.7.0 requires psutil>=5.4.3, which is not installed.
# tf-models-official 2.7.0 requires py-cpuinfo>=3.3.0, which is not installed.
# tf-models-official 2.7.0 requires pycocotools, which is not installed.
# tf-models-official 2.7.0 requires sacrebleu, which is not installed.
# tf-models-official 2.7.0 requires sentencepiece, which is not installed.
# tf-models-official 2.7.0 requires seqeval, which is not installed.
# tf-models-official 2.7.0 requires tensorflow-addons, which is not installed.
# tf-models-official 2.7.0 requires tensorflow-datasets, which is not installed.
# tf-models-official 2.7.0 requires tensorflow-hub>=0.6.0, which is not installed.
# tf-models-official 2.7.0 requires tensorflow-model-optimization>=0.4.1, which is not installed.
# tf-models-official 2.7.0 requires tensorflow-text>=2.7.0, which is not installed.

# %%
# !pip install tensorflow --upgrade
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# object-detection 0.1 requires apache-beam, which is not installed.
# object-detection 0.1 requires avro-python3, which is not installed.
# object-detection 0.1 requires contextlib2, which is not installed.
# object-detection 0.1 requires Cython, which is not installed.
# object-detection 0.1 requires lxml, which is not installed.
# object-detection 0.1 requires matplotlib, which is not installed.
# object-detection 0.1 requires pillow, which is not installed.
# object-detection 0.1 requires pycocotools, which is not installed.
# tf-models-official 2.7.0 requires Cython, which is not installed.
# tf-models-official 2.7.0 requires gin-config, which is not installed.
# tf-models-official 2.7.0 requires google-api-python-client>=1.6.7, which is not installed.
# tf-models-official 2.7.0 requires kaggle>=1.3.9, which is not installed.
# tf-models-official 2.7.0 requires matplotlib, which is not installed.
# tf-models-official 2.7.0 requires oauth2client, which is not installed.
# tf-models-official 2.7.0 requires opencv-python-headless, which is not installed.
# tf-models-official 2.7.0 requires Pillow, which is not installed.
# tf-models-official 2.7.0 requires psutil>=5.4.3, which is not installed.
# tf-models-official 2.7.0 requires py-cpuinfo>=3.3.0, which is not installed.
# tf-models-official 2.7.0 requires pycocotools, which is not installed.
# tf-models-official 2.7.0 requires pyyaml>=5.1, which is not installed.
# tf-models-official 2.7.0 requires sacrebleu, which is not installed.
# tf-models-official 2.7.0 requires sentencepiece, which is not installed.
# tf-models-official 2.7.0 requires seqeval, which is not installed.
# tf-models-official 2.7.0 requires tensorflow-addons, which is not installed.
# tf-models-official 2.7.0 requires tensorflow-datasets, which is not installed.
# tf-models-official 2.7.0 requires tensorflow-hub>=0.6.0, which is not installed.
# tf-models-official 2.7.0 requires tensorflow-model-optimization>=0.4.1, which is not installed.
# tf-models-official 2.7.0 requires tensorflow-text>=2.7.0, which is not installed.
# pandas 1.4.0 requires pytz>=2020.1, which is not installed.
# lvis 0.5.3 requires cycler>=0.10.0, which is not installed.
# lvis 0.5.3 requires Cython>=0.29.12, which is not installed.
# lvis 0.5.3 requires kiwisolver>=1.1.0, which is not installed.
# lvis 0.5.3 requires matplotlib>=3.1.1, which is not installed.
# lvis 0.5.3 requires opencv-python>=4.1.0.25, which is not installed.
# Collecting tensorflow
#   Using cached tensorflow-2.7.0-cp39-cp39-win_amd64.whl (430.8 MB)
# Collecting numpy>=1.14.5
#   Using cached numpy-1.22.1-cp39-cp39-win_amd64.whl (14.7 MB)
# Collecting flatbuffers<3.0,>=1.12
#   Using cached flatbuffers-2.0-py2.py3-none-any.whl (26 kB)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting wheel<1.0,>=0.32.0
#   Using cached wheel-0.37.1-py2.py3-none-any.whl (35 kB)
# Collecting keras<2.8,>=2.7.0rc0
#   Using cached keras-2.7.0-py2.py3-none-any.whl (1.3 MB)
# Collecting tensorflow-estimator<2.8,~=2.7.0rc0
#   Using cached tensorflow_estimator-2.7.0-py2.py3-none-any.whl (463 kB)
# Collecting libclang>=9.0.1
#   Using cached libclang-12.0.0-2-py2.py3-none-win_amd64.whl (13.0 MB)
# Collecting wrapt>=1.11.0
#   Using cached wrapt-1.13.3-cp39-cp39-win_amd64.whl (34 kB)
# Collecting keras-preprocessing>=1.1.1
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Requirement already satisfied: absl-py>=0.4.0 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from tensorflow) (1.0.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from tensorflow) (4.0.1)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting termcolor>=1.1.0
#   Using cached termcolor-1.1.0-py3-none-any.whl
# Collecting grpcio<2.0,>=1.24.3
#   Using cached grpcio-1.43.0-cp39-cp39-win_amd64.whl (3.4 MB)
# Collecting tensorboard~=2.6
#   Using cached tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
# Requirement already satisfied: six>=1.12.0 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from tensorflow) (1.16.0)
# Collecting gast<0.5.0,>=0.2.1
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting h5py>=2.9.0
#   Using cached h5py-3.6.0-cp39-cp39-win_amd64.whl (2.8 MB)
# Collecting tensorflow-io-gcs-filesystem>=0.21.0
#   Using cached tensorflow_io_gcs_filesystem-0.23.1-cp39-cp39-win_amd64.whl (1.5 MB)
# Collecting protobuf>=3.9.2
#   Using cached protobuf-3.19.3-cp39-cp39-win_amd64.whl (895 kB)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from tensorboard~=2.6->tensorflow) (60.5.0)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting google-auth<3,>=1.6.3
#   Using cached google_auth-2.4.1-py2.py3-none-any.whl (157 kB)
# Collecting requests<3,>=2.21.0
#   Using cached requests-2.27.1-py2.py3-none-any.whl (63 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Using cached tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Collecting werkzeug>=0.11.15
#   Using cached Werkzeug-2.0.2-py3-none-any.whl (288 kB)
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.3.6-py3-none-any.whl (97 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Using cached cachetools-5.0.0-py3-none-any.whl (9.1 kB)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.8-py3-none-any.whl (39 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting importlib-metadata>=4.4
#   Using cached importlib_metadata-4.10.1-py3-none-any.whl (17 kB)
# Collecting charset-normalizer~=2.0.0
#   Using cached charset_normalizer-2.0.10-py3-none-any.whl (39 kB)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2021.10.8-py2.py3-none-any.whl (149 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Using cached urllib3-1.26.8-py2.py3-none-any.whl (138 kB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.3-py3-none-any.whl (61 kB)
# Collecting zipp>=0.5
#   Using cached zipp-3.7.0-py3-none-any.whl (5.3 kB)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.1.1-py2.py3-none-any.whl (146 kB)
# Installing collected packages: urllib3, pyasn1, idna, charset-normalizer, certifi, zipp, rsa, requests, pyasn1-modules, oauthlib, cachetools, requests-oauthlib, importlib-metadata, google-auth, wheel, werkzeug, tensorboard-plugin-wit, tensorboard-data-server, protobuf, numpy, markdown, grpcio, google-auth-oauthlib, wrapt, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard, opt-einsum, libclang, keras-preprocessing, keras, h5py, google-pasta, gast, flatbuffers, astunparse, tensorflow
#   Attempting uninstall: keras
#     Found existing installation: keras 2.8.0rc1
#     Uninstalling keras-2.8.0rc1:
#       Successfully uninstalled keras-2.8.0rc1
# Successfully installed astunparse-1.6.3 cachetools-5.0.0 certifi-2021.10.8 charset-normalizer-2.0.10 flatbuffers-2.0 gast-0.4.0 google-auth-2.4.1 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.43.0 h5py-3.6.0 idna-3.3 importlib-metadata-4.10.1 keras-2.7.0 keras-preprocessing-1.1.2 libclang-12.0.0 markdown-3.3.6 numpy-1.22.1 oauthlib-3.1.1 opt-einsum-3.3.0 protobuf-3.19.3 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-2.27.1 requests-oauthlib-1.3.0 rsa-4.8 tensorboard-2.8.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.7.0 tensorflow-estimator-2.7.0 tensorflow-io-gcs-filesystem-0.23.1 termcolor-1.1.0 urllib3-1.26.8 werkzeug-2.0.2 wheel-0.37.1 wrapt-1.13.3 zipp-3.7.0

# %%
# !pip install tensorflow-gpu --upgrade
# Out:
# Collecting tensorflow-gpu
#   Using cached tensorflow_gpu-2.7.0-cp39-cp39-win_amd64.whl (430.8 MB)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from tensorflow-gpu) (4.0.1)
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from tensorflow-gpu) (0.4.0)
# Requirement already satisfied: tensorflow-estimator<2.8,~=2.7.0rc0 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from tensorflow-gpu) (2.7.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from tensorflow-gpu) (0.23.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from tensorflow-gpu) (1.43.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from tensorflow-gpu) (1.13.3)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from tensorflow-gpu) (1.22.1)
# Requirement already satisfied: libclang>=9.0.1 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from tensorflow-gpu) (12.0.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from tensorflow-gpu) (3.19.3)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from tensorflow-gpu) (0.37.1)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from tensorflow-gpu) (2.0)
# Requirement already satisfied: keras<2.8,>=2.7.0rc0 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from tensorflow-gpu) (2.7.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from tensorflow-gpu) (1.16.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from tensorflow-gpu) (3.3.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from tensorflow-gpu) (3.6.0)
# Requirement already satisfied: absl-py>=0.4.0 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from tensorflow-gpu) (1.0.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from tensorflow-gpu) (1.1.2)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from tensorflow-gpu) (1.6.3)
# Requirement already satisfied: tensorboard~=2.6 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from tensorflow-gpu) (2.8.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from tensorflow-gpu) (1.1.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from tensorflow-gpu) (0.2.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from tensorboard~=2.6->tensorflow-gpu) (60.5.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from tensorboard~=2.6->tensorflow-gpu) (2.27.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from tensorboard~=2.6->tensorflow-gpu) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from tensorboard~=2.6->tensorflow-gpu) (0.4.6)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from tensorboard~=2.6->tensorflow-gpu) (2.0.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from tensorboard~=2.6->tensorflow-gpu) (3.3.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from tensorboard~=2.6->tensorflow-gpu) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from tensorboard~=2.6->tensorflow-gpu) (2.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow-gpu) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow-gpu) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow-gpu) (5.0.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow-gpu) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow-gpu) (4.10.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow-gpu) (1.26.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow-gpu) (2.0.10)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow-gpu) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow-gpu) (2021.10.8)
# Requirement already satisfied: zipp>=0.5 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.6->tensorflow-gpu) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow-gpu) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow-gpu) (3.1.1)
# Installing collected packages: tensorflow-gpu
# Successfully installed tensorflow-gpu-2.7.0

# %%
# !pip uninstall matplotlib -y
# !pip install matplotlib
# Out:
# WARNING: Skipping matplotlib as it is not installed.
# Collecting matplotlib
#   Using cached matplotlib-3.5.1-cp39-cp39-win_amd64.whl (7.2 MB)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from matplotlib) (21.3)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.29.0-py3-none-any.whl (895 kB)
# Collecting pillow>=6.2.0
#   Using cached Pillow-9.0.0-cp39-cp39-win_amd64.whl (3.2 MB)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from matplotlib) (3.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from matplotlib) (1.22.1)
# Requirement already satisfied: six>=1.5 in c:\users\xavie\documents\github\coursework\tfod\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pillow, fonttools, matplotlib
# Successfully installed fonttools-4.29.0 matplotlib-3.5.1 pillow-9.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# object-detection 0.1 requires apache-beam, which is not installed.
# object-detection 0.1 requires avro-python3, which is not installed.
# object-detection 0.1 requires contextlib2, which is not installed.
# object-detection 0.1 requires Cython, which is not installed.
# object-detection 0.1 requires lxml, which is not installed.
# object-detection 0.1 requires pycocotools, which is not installed.
# tf-models-official 2.7.0 requires Cython, which is not installed.
# tf-models-official 2.7.0 requires gin-config, which is not installed.
# tf-models-official 2.7.0 requires google-api-python-client>=1.6.7, which is not installed.
# tf-models-official 2.7.0 requires kaggle>=1.3.9, which is not installed.
# tf-models-official 2.7.0 requires oauth2client, which is not installed.
# tf-models-official 2.7.0 requires opencv-python-headless, which is not installed.
# tf-models-official 2.7.0 requires psutil>=5.4.3, which is not installed.
# tf-models-official 2.7.0 requires py-cpuinfo>=3.3.0, which is not installed.
# tf-models-official 2.7.0 requires pycocotools, which is not installed.
# tf-models-official 2.7.0 requires pyyaml>=5.1, which is not installed.
# tf-models-official 2.7.0 requires sacrebleu, which is not installed.
# tf-models-official 2.7.0 requires sentencepiece, which is not installed.
# tf-models-official 2.7.0 requires seqeval, which is not installed.
# tf-models-official 2.7.0 requires tensorflow-addons, which is not installed.
# tf-models-official 2.7.0 requires tensorflow-datasets, which is not installed.
# tf-models-official 2.7.0 requires tensorflow-hub>=0.6.0, which is not installed.
# tf-models-official 2.7.0 requires tensorflow-model-optimization>=0.4.1, which is not installed.
# tf-models-official 2.7.0 requires tensorflow-text>=2.7.0, which is not installed.
# lvis 0.5.3 requires Cython>=0.29.12, which is not installed.
# lvis 0.5.3 requires opencv-python>=4.1.0.25, which is not installed.

# %%
import object_detection

# %%
# !pip list
# Out:
# Package                      Version   Editable project location
# ---------------------------- --------- --------------------------------------------------------------------------
# absl-py                      1.0.0
# argon2-cffi                  21.3.0
# argon2-cffi-bindings         21.2.0
# asttokens                    2.0.5
# astunparse                   1.6.3
# attrs                        21.4.0
# backcall                     0.2.0
# black                        21.12b0
# bleach                       4.1.0
# cachetools                   5.0.0
# certifi                      2021.10.8
# cffi                         1.15.0
# charset-normalizer           2.0.10
# click                        8.0.3
# colorama                     0.4.4
# cycler                       0.11.0
# debugpy                      1.5.1
# decorator                    5.1.1
# defusedxml                   0.7.1
# entrypoints                  0.3
# executing                    0.8.2
# flatbuffers                  2.0
# fonttools                    4.29.0
# gast                         0.4.0
# google-auth                  2.4.1
# google-auth-oauthlib         0.4.6
# google-pasta                 0.2.0
# grpcio                       1.43.0
# h5py                         3.6.0
# idna                         3.3
# importlib-metadata           4.10.1
# ipykernel                    6.7.0
# ipython                      8.0.1
# ipython-genutils             0.2.0
# ipywidgets                   7.6.5
# jedi                         0.18.1
# Jinja2                       3.0.3
# jsonschema                   4.4.0
# jupyter                      1.0.0
# jupyter-client               7.1.2
# jupyter-console              6.4.0
# jupyter-core                 4.9.1
# jupyterlab-pygments          0.1.2
# jupyterlab-widgets           1.0.2
# keras                        2.7.0
# Keras-Preprocessing          1.1.2
# kiwisolver                   1.3.2
# libclang                     12.0.0
# lvis                         0.5.3
# Markdown                     3.3.6
# MarkupSafe                   2.0.1
# matplotlib                   3.5.1
# matplotlib-inline            0.1.3
# mistune                      0.8.4
# mypy-extensions              0.4.3
# nbclient                     0.5.10
# nbconvert                    6.4.0
# nbformat                     5.1.3
# nest-asyncio                 1.5.4
# notebook                     6.4.7
# numpy                        1.22.1
# oauthlib                     3.1.1
# object-detection             0.1
# opt-einsum                   3.3.0
# packaging                    21.3
# pandas                       1.4.0
# pandocfilters                1.5.0
# parso                        0.8.3
# pathspec                     0.9.0
# pickleshare                  0.7.5
# Pillow                       9.0.0
# pip                          21.3.1
# platformdirs                 2.4.1
# prometheus-client            0.12.0
# prompt-toolkit               3.0.24
# protobuf                     3.19.3
# pure-eval                    0.2.2
# pyasn1                       0.4.8
# pyasn1-modules               0.2.8
# pycparser                    2.21
# Pygments                     2.11.2
# pyparsing                    3.0.7
# pyrsistent                   0.18.1
# python-dateutil              2.8.2
# pywin32                      303
# pywinpty                     1.1.6
# PyYAML                       6.0
# pyzmq                        22.3.0
# qtconsole                    5.2.2
# QtPy                         2.0.0
# requests                     2.27.1
# requests-oauthlib            1.3.0
# rsa                          4.8
# scipy                        1.8.0rc3
# Send2Trash                   1.8.0
# setuptools                   60.5.0
# six                          1.16.0
# slim                         0.1       c:\users\xavie\documents\github\coursework\tensorflow\models\research\slim
# stack-data                   0.1.4
# tensorboard                  2.8.0
# tensorboard-data-server      0.6.1
# tensorboard-plugin-wit       1.8.1
# tensorflow                   2.7.0
# tensorflow-estimator         2.7.0
# tensorflow-gpu               2.7.0
# tensorflow-io                0.23.1
# tensorflow-io-gcs-filesystem 0.23.1
# termcolor                    1.1.0
# terminado                    0.12.1
# testpath                     0.5.0
# tf-models-official           2.7.0
# tf-slim                      1.1.0
# tomli                        1.2.3
# tornado                      6.1
# traitlets                    5.1.1
# typing_extensions            4.0.1
# urllib3                      1.26.8
# wcwidth                      0.2.5
# webencodings                 0.5.1
# Werkzeug                     2.0.2
# wget                         3.2
# wheel                        0.37.1
# widgetsnbextension           3.5.2
# wrapt                        1.13.3
# zipp                         3.7.0

# %%
if os.name =='posix':
    # !wget {PRETRAINED_MODEL_URL}
    # !mv {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
if os.name == 'nt':
    wget.download(PRETRAINED_MODEL_URL)
    # !move {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
# Out:
#   7% [.....                                                                   ]  1630208 / 20515344
#  21% [...............                                                         ]  4456448 / 20515344
#  34% [.........................                                               ]  7151616 / 20515344
#  48% [..................................                                      ]  9961472 / 20515344
#  62% [............................................                            ] 12771328 / 20515344
#  76% [......................................................                  ] 15630336 / 20515344
#  90% [................................................................        ] 18489344 / 20515344
# 100% [........................................................................] 20515344 / 20515344
#         1 file(s) moved.
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.data-00000-of-00001
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/checkpoint
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.index
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/pipeline.config
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/saved_model.pb
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/variables.data-00000-of-00001
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/variables.index

# %% [markdown]
# # 2. Create Label Map

# %%
labels = [{'name':'a', 'id':1}, {'name':'b', 'id':2}, {'name':'c', 'id':3}, {'name':'d', 'id':4}, {'name':'e', 'id':5}, {'name':'f', 'id':6}, {'name':'g', 'id':7}, {'name':'h', 'id':8}, {'name':'i', 'id':9}, {'name':'j', 'id':10}, {'name':'k', 'id':11}, {'name':'l', 'id':12}, {'name':'m', 'id':13}, {'name':'n', 'id':14}, {'name':'o', 'id':15}, {'name':'p', 'id':16}, {'name':'q', 'id':17}, {'name':'r', 'id':18}, {'name':'s', 'id':19}, {'name':'t', 'id':20}, {'name':'u', 'id':21}, {'name':'v', 'id':22}, {'name':'w', 'id':23}, {'name':'x', 'id':24}, {'name':'y', 'id':25}, {'name':'z', 'id':26}]
with open(files['LABELMAP'], 'w') as f:
    for label in labels:
        f.write('item { \n')
        f.write('\tname:\'{}\'\n'.format(label['name']))
        f.write('\tid:{}\n'.format(label['id']))
        f.write('}\n')

# %% [markdown]
# # 3. Create TF records

# %%
# OPTIONAL IF RUNNING ON COLAB
ARCHIVE_FILES = os.path.join(paths['IMAGE_PATH'], 'archive.tar.gz')
if os.path.exists(ARCHIVE_FILES):
  # !tar -zxvf {ARCHIVE_FILES}

# %%
if not os.path.exists(files['TF_RECORD_SCRIPT']):
    # !git clone https://github.com/nicknochnack/GenerateTFRecord {paths['SCRIPTS_PATH']}

# %%
# !pip install pytz
# Out:
# Collecting pytz
#   Using cached pytz-2021.3-py2.py3-none-any.whl (503 kB)
# Installing collected packages: pytz
# Successfully installed pytz-2021.3

# %%
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'train')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'train.record')} 
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'test')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'test.record')}
# Out:
# Successfully created the TFRecord file: Tensorflow\workspace\annotations\train.record
# Successfully created the TFRecord file: Tensorflow\workspace\annotations\test.record

# %% [markdown]
# # 4. Copy Model Config to Training Folder

# %%
if os.name =='posix':
    # !cp {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
if os.name == 'nt':
    # !copy {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
# Out:
#         1 file(s) copied.

# %% [markdown]
# # 5. Update Config For Transfer Learning

# %%
import tensorflow as tf
from object_detection.utils import config_util
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format

# %%
config = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])

# %%
config
# Out:
# {'model': ssd {
#    num_classes: 90
#    image_resizer {
#      fixed_shape_resizer {
#        height: 320
#        width: 320
#      }
#    }
#    feature_extractor {
#      type: "ssd_mobilenet_v2_fpn_keras"
#      depth_multiplier: 1.0
#      min_depth: 16
#      conv_hyperparams {
#        regularizer {
#          l2_regularizer {
#            weight: 3.9999998989515007e-05
#          }
#        }
#        initializer {
#          random_normal_initializer {
#            mean: 0.0
#            stddev: 0.009999999776482582
#          }
#        }
#        activation: RELU_6
#        batch_norm {
#          decay: 0.996999979019165
#          scale: true
#          epsilon: 0.0010000000474974513
#        }
#      }
#      use_depthwise: true
#      override_base_feature_extractor_hyperparams: true
#      fpn {
#        min_level: 3
#        max_level: 7
#        additional_layer_depth: 128
#      }
#    }
#    box_coder {
#      faster_rcnn_box_coder {
#        y_scale: 10.0
#        x_scale: 10.0
#        height_scale: 5.0
#        width_scale: 5.0
#      }
#    }
#    matcher {
#      argmax_matcher {
#        matched_threshold: 0.5
#        unmatched_threshold: 0.5
#        ignore_thresholds: false
#        negatives_lower_than_unmatched: true
#        force_match_for_each_row: true
#        use_matmul_gather: true
#      }
#    }
#    similarity_calculator {
#      iou_similarity {
#      }
#    }
#    box_predictor {
#      weight_shared_convolutional_box_predictor {
#        conv_hyperparams {
#          regularizer {
#            l2_regularizer {
#              weight: 3.9999998989515007e-05
#            }
#          }
#          initializer {
#            random_normal_initializer {
#              mean: 0.0
#              stddev: 0.009999999776482582
#            }
#          }
#          activation: RELU_6
#          batch_norm {
#            decay: 0.996999979019165
#            scale: true
#            epsilon: 0.0010000000474974513
#          }
#        }
#        depth: 128
#        num_layers_before_predictor: 4
#        kernel_size: 3
#        class_prediction_bias_init: -4.599999904632568
#        share_prediction_tower: true
#        use_depthwise: true
#      }
#    }
#    anchor_generator {
#      multiscale_anchor_generator {
#        min_level: 3
#        max_level: 7
#        anchor_scale: 4.0
#        aspect_ratios: 1.0
#        aspect_ratios: 2.0
#        aspect_ratios: 0.5
#        scales_per_octave: 2
#      }
#    }
#    post_processing {
#      batch_non_max_suppression {
#        score_threshold: 9.99999993922529e-09
#        iou_threshold: 0.6000000238418579
#        max_detections_per_class: 100
#        max_total_detections: 100
#        use_static_shapes: false
#      }
#      score_converter: SIGMOID
#    }
#    normalize_loss_by_num_matches: true
#    loss {
#      localization_loss {
#        weighted_smooth_l1 {
#        }
#      }
#      classification_loss {
#        weighted_sigmoid_focal {
#          gamma: 2.0
#          alpha: 0.25
#        }
#      }
#      classification_weight: 1.0
#      localization_weight: 1.0
#    }
#    encode_background_as_zeros: true
#    normalize_loc_loss_by_codesize: true
#    inplace_batchnorm_update: true
#    freeze_batchnorm: false
#  },
#  'train_config': batch_size: 128
#  data_augmentation_options {
#    random_horizontal_flip {
#    }
#  }
#  data_augmentation_options {
#    random_crop_image {
#      min_object_covered: 0.0
#      min_aspect_ratio: 0.75
#      max_aspect_ratio: 3.0
#      min_area: 0.75
#      max_area: 1.0
#      overlap_thresh: 0.0
#    }
#  }
#  sync_replicas: true
#  optimizer {
#    momentum_optimizer {
#      learning_rate {
#        cosine_decay_learning_rate {
#          learning_rate_base: 0.07999999821186066
#          total_steps: 50000
#          warmup_learning_rate: 0.026666000485420227
#          warmup_steps: 1000
#        }
#      }
#      momentum_optimizer_value: 0.8999999761581421
#    }
#    use_moving_average: false
#  }
#  fine_tune_checkpoint: "PATH_TO_BE_CONFIGURED"
#  num_steps: 50000
#  startup_delay_steps: 0.0
#  replicas_to_aggregate: 8
#  max_number_of_boxes: 100
#  unpad_groundtruth_tensors: false
#  fine_tune_checkpoint_type: "classification"
#  fine_tune_checkpoint_version: V2,
#  'train_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  },
#  'eval_config': metrics_set: "coco_detection_metrics"
#  use_moving_averages: false,
#  'eval_input_configs': [label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }
#  ],
#  'eval_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }}

# %%
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "r") as f:                                                                                                                                                                                                                     
    proto_str = f.read()                                                                                                                                                                                                                                          
    text_format.Merge(proto_str, pipeline_config)

# %%
pipeline_config.model.ssd.num_classes = len(labels)
pipeline_config.train_config.batch_size = 4
pipeline_config.train_config.fine_tune_checkpoint = os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'checkpoint', 'ckpt-0')
pipeline_config.train_config.fine_tune_checkpoint_type = "detection"
pipeline_config.train_input_reader.label_map_path= files['LABELMAP']
pipeline_config.train_input_reader.tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'train.record')]
pipeline_config.eval_input_reader[0].label_map_path = files['LABELMAP']
pipeline_config.eval_input_reader[0].tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'test.record')]

# %%
config_text = text_format.MessageToString(pipeline_config)                                                                                                                                                                                                        
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "wb") as f:                                                                                                                                                                                                                     
    f.write(config_text)

# %% [markdown]
# # 6. Train the model

# %%
TRAINING_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'model_main_tf2.py')

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --num_train_steps=2000".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'])

# %%
print(command)
# Out:
# python Tensorflow\models\research\object_detection\model_main_tf2.py --model_dir=Tensorflow\workspace\models\my_ssd_mobnet --pipeline_config_path=Tensorflow\workspace\models\my_ssd_mobnet\pipeline.config --num_train_steps=2000

# %%
# !{command}

# %% [markdown]
# # 7. Evaluate the Model

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --checkpoint_dir={}".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'])

# %%
print(command)
# Out:
# python Tensorflow\models\research\object_detection\model_main_tf2.py --model_dir=Tensorflow\workspace\models\my_ssd_mobnet --pipeline_config_path=Tensorflow\workspace\models\my_ssd_mobnet\pipeline.config --checkpoint_dir=Tensorflow\workspace\models\my_ssd_mobnet

# %%
# !{command}

# %% [markdown]
# # 8. Load Train Model From Checkpoint

# %%
import os
import tensorflow as tf
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.builders import model_builder
from object_detection.utils import config_util

# %%
# Load pipeline config and build a detection model
configs = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])
detection_model = model_builder.build(model_config=configs['model'], is_training=False)

# Restore checkpoint
ckpt = tf.compat.v2.train.Checkpoint(model=detection_model)
ckpt.restore(os.path.join(paths['CHECKPOINT_PATH'], 'ckpt-11')).expect_partial()

@tf.function
def detect_fn(image):
    image, shapes = detection_model.preprocess(image)
    prediction_dict = detection_model.predict(image, shapes)
    detections = detection_model.postprocess(prediction_dict, shapes)
    return detections

# %% [markdown]
# # 9. Detect from an Image

# %%
import cv2 
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
category_index = label_map_util.create_category_index_from_labelmap(files['LABELMAP'])

# %%
IMAGE_PATH = os.path.join(paths['IMAGE_PATH'], 'test', 'a13.jpg')

# %%
img = cv2.imread(IMAGE_PATH)
image_np = np.array(img)

input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
detections = detect_fn(input_tensor)

num_detections = int(detections.pop('num_detections'))
detections = {key: value[0, :num_detections].numpy()
              for key, value in detections.items()}
detections['num_detections'] = num_detections

# detection_classes should be ints.
detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

label_id_offset = 1
image_np_with_detections = image_np.copy()

viz_utils.visualize_boxes_and_labels_on_image_array(
            image_np_with_detections,
            detections['detection_boxes'],
            detections['detection_classes']+label_id_offset,
            detections['detection_scores'],
            category_index,
            use_normalized_coordinates=True,
            max_boxes_to_draw=5,
            min_score_thresh=.8,
            agnostic_mode=False)

plt.imshow(cv2.cvtColor(image_np_with_detections, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# # 10. Real Time Detections from your Webcam

# %%
# !pip uninstall opencv-python-headless -y

# %%
cap = cv2.VideoCapture(0)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

while cap.isOpened(): 
    ret, frame = cap.read()
    image_np = np.array(frame)
    
    input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
    detections = detect_fn(input_tensor)
    
    num_detections = int(detections.pop('num_detections'))
    detections = {key: value[0, :num_detections].numpy()
                  for key, value in detections.items()}
    detections['num_detections'] = num_detections

    # detection_classes should be ints.
    detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

    label_id_offset = 1
    image_np_with_detections = image_np.copy()

    viz_utils.visualize_boxes_and_labels_on_image_array(
                image_np_with_detections,
                detections['detection_boxes'],
                detections['detection_classes']+label_id_offset,
                detections['detection_scores'],
                category_index,
                use_normalized_coordinates=True,
                max_boxes_to_draw=5,
                min_score_thresh=.8,
                agnostic_mode=False)

    cv2.imshow('object detection',  cv2.resize(image_np_with_detections, (800, 600)))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        cap.release()
        cv2.destroyAllWindows()
        break

# %% [markdown]
# # 10. Freezing the Graph

# %%
FREEZE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'exporter_main_v2.py ')

# %%
command = "py {} --input_type=image_tensor --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(FREEZE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['OUTPUT_PATH'])

# %%
print(command)
# Out:
# py Tensorflow\models\research\object_detection\exporter_main_v2.py  --input_type=image_tensor --pipeline_config_path=Tensorflow\workspace\models\my_ssd_mobnet\pipeline.config --trained_checkpoint_dir=Tensorflow\workspace\models\my_ssd_mobnet --output_directory=Tensorflow\workspace\models\my_ssd_mobnet\export

# %%
# !{command}
# Out:
# C:\Users\xavie\AppData\Local\Programs\Python\Python39\python.exe: can't open file 'C:\Users\xavie\Downloads\coursework\Tensorflow\models\research\object_detection\exporter_main_v2.py': [Errno 2] No such file or directory

# %% [markdown]
# # 11. Conversion to TFJS

# %%
# !pip install tensorflowjs

# %%
command = "tensorflowjs_converter --input_format=tf_saved_model --output_node_names='detection_boxes,detection_classes,detection_features,detection_multiclass_scores,detection_scores,num_detections,raw_detection_boxes,raw_detection_scores' --output_format=tfjs_graph_model --signature_name=serving_default {} {}".format(os.path.join(paths['OUTPUT_PATH'], 'saved_model'), paths['TFJS_PATH'])

# %%
print(command)

# %%
# !{command}

# %%
# Test Code: https://github.com/nicknochnack/RealTimeSignLanguageDetectionwithTFJS

# %% [markdown]
# # 12. Conversion to TFLite

# %%
TFLITE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'export_tflite_graph_tf2.py ')

# %%
command = "python {} --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(TFLITE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['TFLITE_PATH'])

# %%
print(command)

# %%
# !{command}

# %%
FROZEN_TFLITE_PATH = os.path.join(paths['TFLITE_PATH'], 'saved_model')
TFLITE_MODEL = os.path.join(paths['TFLITE_PATH'], 'saved_model', 'detect.tflite')

# %%
command = "tflite_convert \
--saved_model_dir={} \
--output_file={} \
--input_shapes=1,300,300,3 \
--input_arrays=normalized_input_image_tensor \
--output_arrays='TFLite_Detection_PostProcess','TFLite_Detection_PostProcess:1','TFLite_Detection_PostProcess:2','TFLite_Detection_PostProcess:3' \
--inference_type=FLOAT \
--allow_custom_ops".format(FROZEN_TFLITE_PATH, TFLITE_MODEL, )

# %%
print(command)

# %%
# !{command}

# %% [markdown]
# # 13. Zip and Export Models

# %%
# !tar -czf models.tar.gz {paths['CHECKPOINT_PATH']}

# %%
from google.colab import drive
drive.mount('/content/drive')
